# %%
import os

# %% [markdown]
# # step.03.snk.quantify_for_every_region

# %%
# LIB
ls = [i.replace('TargetSeq-','') for i in os.listdir('..') if 'TargetSeq-' in i]
ls.sort()
print('all lib:')
ls
# Out:
# all lib:
# ['E-digenome-only-5-1', 'E-digenome-only-5-2']

# %%
# REGION
ls = []
for i in [i for i in os.listdir('..') if "TargetSeq-" in i]:
    for j in os.listdir(os.path.join("..",i,"demultiplex.fastq")):
        ls.append(j.replace("_demultiplex_R2.fastq",'').replace("_demultiplex_R1.fastq",""))
ls = list(set(ls))
ls.sort()
ls
# Out:
# ['Digenome-only-EMX1-off-target-11',
#  'Digenome-only-EMX1-off-target-12',
#  'Digenome-only-EMX1-off-target-13',
#  'Digenome-only-EMX1-off-target-15',
#  'Digenome-only-EMX1-off-target-16',
#  'Digenome-only-EMX1-off-target-17',
#  'Digenome-only-EMX1-off-target-22',
#  'Digenome-only-EMX1-off-target-23']

# %% [markdown]
# # step.04.snk.merge_fastq_pipline

# %%
ls = [i.replace('TargetSeq-','') for i in os.listdir('..') if 'TargetSeq-' in i]
ls.sort()
print('all lib:')
ls
# Out:
# all lib:
# ['E-digenome-only-5-1', 'E-digenome-only-5-2']

# %% [markdown]
# # step.05.snk.getfasta

# %%
ls = []
for i in [i for i in os.listdir('..') if "TargetSeq-" in i]:
    for j in os.listdir(os.path.join("..",i,"demultiplex.fastq")):
        ls.append(j.replace("_demultiplex_R2.fastq",'').replace("_demultiplex_R1.fastq",""))
ls = list(set(ls))
ls.sort()
ls
# Out:
# ['Digenome-only-EMX1-off-target-11',
#  'Digenome-only-EMX1-off-target-12',
#  'Digenome-only-EMX1-off-target-13',
#  'Digenome-only-EMX1-off-target-15',
#  'Digenome-only-EMX1-off-target-16',
#  'Digenome-only-EMX1-off-target-17',
#  'Digenome-only-EMX1-off-target-22',
#  'Digenome-only-EMX1-off-target-23']

# %% [markdown]
# # step.06.snk.merge_fastq_to_plot_pipline.bwa

# %%
# SAMPLE:   PRIMER:

# index = '5-6-7'
# index = '8-9-10'
# index = '11-12-13'
# index = '14-15'
# index = 'duigou-jiantou'
index = 'EMX1-DigenomeOnly'
path = './primer_table/{index}.txt'.format(index=index)
f = open(path,'r')
[i.split("\t")[3] for i in f.readlines()[1:]]
# Out:
# ['Digenome-only-EMX1-off-target-11',
#  'Digenome-only-EMX1-off-target-12',
#  'Digenome-only-EMX1-off-target-13',
#  'Digenome-only-EMX1-off-target-15',
#  'Digenome-only-EMX1-off-target-16',
#  'Digenome-only-EMX1-off-target-17',
#  'Digenome-only-EMX1-off-target-22',
#  'Digenome-only-EMX1-off-target-23']

# %%
# LIB:
ls = [i.replace('TargetSeq-','') for i in os.listdir('..') if 'TargetSeq-' in i]
ls.sort()
print('all lib:')
ls
# Out:
# all lib:
# ['E-digenome-only-5-1', 'E-digenome-only-5-2']

# %% [markdown]
# # step.07.MultiTargetPlot

# %%
# 注意，只提取一组！拥有共同site的lib，否则自己定义lib和site
ls = []
for i in [i for i in os.listdir('..') if "TargetSeq-" in i]:
    for j in os.listdir(os.path.join("..",i,"demultiplex.fastq")):
        ls.append(j.replace("_demultiplex_R2.fastq",'').replace("_demultiplex_R1.fastq",""))
ls = list(set(ls))
ls.sort()
ls_site = ls

ls = [i.replace('TargetSeq-','') for i in os.listdir('..') if 'TargetSeq-' in i]
ls.sort()
ls_lib = ls

# ls_site = ['diy']
# ls_lib = ['diy']
# ls_site = ['EMX1-Guideseq-1', 'EMX1-Guideseq-2']
# ls_lib = ['GBE-33A', 'GBE-M2', 'GBEmini-33A', 'GBEmini-M2']
ls_lib
# Out:
# ['1341P',
#  'DddA-nes',
#  'DddIA-1-1-0.5',
#  'DddIA-1-1-1',
#  'DddIA-1-1-1.5',
#  'ND6-WT',
#  'TALE-nes',
#  'UGI-nes']

# %%
ls_lib = [ 'ND6-WT','1341P','TALE-nes','DddA-nes','UGI-nes','DddIA-1-1-0.5','DddIA-1-1-1',
 'DddIA-1-1-1.5']
ls_lib
# Out:
# ['ND6-WT',
#  '1341P',
#  'TALE-nes',
#  'DddA-nes',
#  'UGI-nes',
#  'DddIA-1-1-0.5',
#  'DddIA-1-1-1',
#  'DddIA-1-1-1.5']

# %%
PYTHON = "/home/zhaohuanan/miniconda3/envs/snakepipes_target-seq-from-table-to-plot/bin/python"
cutoff = 5
MERGE_NAME = "20201105_DdCBE"
for site in ls_site:
    ls_bmat = []
    ls_label = []
    for lib_ in ls_lib:
        path = "../TargetSeq-{lib}/cutoff_{cutoff}/mapping/{site}_bwa_sort.bmat".format(lib=lib_,cutoff=cutoff,site=site)
        ls_bmat.append(path)
        ls_label.append(lib_)
    bmats = ','.join(ls_bmat)
    labels = ','.join(ls_label)
    sgRNA_PATH = '../TargetSeq_BED_sample_lib/' + site + '.sgRNA.upper.fa.seq'
    with open(sgRNA_PATH,'r') as f:
        sgRNA = f.readlines()[0].strip()
    cmd = """{PYTHON} ./program/multiplot-targetseq-bmat-heatmap-V1.py \
    -i {ls_bmat} -l {ls_label} --to_base A,G,C,T,Ins,Del --count_ratio all \
    -o '../all_plot/{MERGE_NAME}_{site}_cutoff_{cutoff}_count_ratio.pdf' \
    --mut_direction "CT,GA" \
    --plot_heatmap '../all_plot/{MERGE_NAME}_{site}_cutoff_{cutoff}__heatmap.pdf' \
    --region_extend_length 5 \
    --sgRNA {sgRNA} """.format(PYTHON=PYTHON,MERGE_NAME=MERGE_NAME,ls_bmat=bmats,ls_label=labels, site=site, cutoff=cutoff,sgRNA=sgRNA)
#     print(cmd)
    status = os.system(cmd)
    print(status)
print('done')
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# done
