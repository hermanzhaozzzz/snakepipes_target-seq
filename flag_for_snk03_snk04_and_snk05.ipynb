# %%
import os

# %% [markdown]
# # for snk03

# %%
ls = [i.replace('TargetSeq-','') for i in os.listdir('..') if 'TargetSeq-' in i]
ls.sort()
print('all lib:')
ls
# Out:
# all lib:
# ['GBE-33A', 'GBE-M2', 'GBEmini-33A', 'GBEmini-M2']

# %% [markdown]
# # for snk04

# %%
ls = []
for i in [i for i in os.listdir('..') if "TargetSeq-" in i]:
    for j in os.listdir(os.path.join("..",i,"demultiplex.fastq")):
        ls.append(j.replace("_demultiplex_R2.fastq",'').replace("_demultiplex_R1.fastq",""))
ls = list(set(ls))
ls.sort()
ls
# Out:
# ['EMX1-Guideseq-1',
#  'EMX1-Guideseq-2',
#  'EMX1-Guideseq-3',
#  'EMX1-Guideseq-4',
#  'EMX1-Guideseq-5',
#  'EMX1-On-Target',
#  'FANCF-Guideseq-1',
#  'FANCF-Guideseq-2',
#  'FANCF-Guideseq-3',
#  'FANCF-Guideseq-6',
#  'FANCF-On-Target',
#  'HEK2-Guideseq-1',
#  'HEK2-Guideseq-2',
#  'HEK2-On-Target',
#  'HEK4-Guideseq-1',
#  'HEK4-Guideseq-2',
#  'HEK4-Guideseq-3',
#  'HEK4-Guideseq-4',
#  'HEK4-Guideseq-5',
#  'HEK4-On-Target']

# %% [markdown]
# # for snk05

# %%
# index = '5-6-7'
# index = '8-9-10'
# index = '11-12-13'
# index = '14-15'
# index = 'duigou-jiantou'
index = 'all'
path = './primer_table/{index}.txt'.format(index=index)
f = open(path,'r')
[i.split("\t")[3] for i in f.readlines()[1:]]
# Out:
# ['EMX1-On-Target',
#  'EMX1-Guideseq-1',
#  'EMX1-Guideseq-2',
#  'EMX1-Guideseq-3',
#  'EMX1-Guideseq-4',
#  'EMX1-Guideseq-5',
#  'HEK2-On-Target',
#  'HEK2-Guideseq-1',
#  'HEK2-Guideseq-2',
#  'HEK4-On-Target',
#  'HEK4-Guideseq-1',
#  'HEK4-Guideseq-2',
#  'HEK4-Guideseq-3',
#  'HEK4-Guideseq-4',
#  'HEK4-Guideseq-5',
#  'FANCF-On-Target',
#  'FANCF-Guideseq-1',
#  'FANCF-Guideseq-2',
#  'FANCF-Guideseq-3',
#  'FANCF-Guideseq-6']
